# %% [markdown]
# #Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# ## Data Import and first Inspection

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv("/content/movies_complete.csv", parse_dates= ["release_date"])

# %%
df.head(1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18635 entries, 0 to 18634
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     18635 non-null  int64
#  1   title                  18635 non-null  object
#  2   tagline                11161 non-null  object
#  3   release_date           18631 non-null  datetime64[ns]
#  4   genres                 18285 non-null  object
#  5   belongs_to_collection  2265 non-null   object
#  6   original_language      18634 non-null  object
#  7   budget_musd            5661 non-null   float64
#  8   revenue_musd           5295 non-null   float64
#  9   production_companies   15608 non-null  object
#  10  production_countries   17236 non-null  object
#  11  vote_count             18634 non-null  float64
#  12  vote_average           18225 non-null  float64
#  13  popularity             18634 non-null  float64
#  14  runtime                18440 non-null  float64
#  15  overview               18506 non-null  object
#  16  spoken_languages       17827 non-null  object
#  17  poster_path            18605 non-null  object
#  18  cast                   18191 non-null  object
#  19  cast_size              18634 non-null  float64
#  20  crew_size              18634 non-null  float64
#  21  director               18514 non-null  object
# dtypes: datetime64[ns](1), float64(8), int64(1), object(12)
# memory usage: 3.1+ MB

# %% [markdown]
# __Features__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
df.describe()
# Out:
#              id  budget_musd  revenue_musd  vote_count  vote_average  \
# count  18635.00      5661.00       5295.00    18634.00      18225.00
# mean   39044.50        24.20         67.97      170.44          6.19
# std    44389.19        33.20        133.39      582.08          1.07
# min        2.00         0.00          0.00        0.00          0.00
# 25%    11813.00         3.00          4.36        7.00          5.60
# 50%    26769.00        12.00         20.60       22.00          6.30
# 75%    47810.50        30.00         71.46       83.00          6.90
# max   449677.00       380.00       2787.97    14075.00         10.00
#
#        popularity  runtime  cast_size  crew_size
# count    18634.00 18440.00   18634.00   18634.00
# mean         4.20   102.73      15.04      13.29
# std          4.87    27.72      13.52      18.53
# min          0.00     1.00       0.00       0.00
# 25%          0.85    90.00       8.00       3.00
# 50%          2.44    99.00      12.00       9.00
# 75%          6.58   111.00      18.00      15.00
# max        185.07   931.00     313.00     338.00

# %%
df.hist(figsize = (20, 12), bins = 100)
plt.show()

# %%
df.budget_musd.value_counts(dropna = False).head(20)
# Out:
# NaN      12974
# 20.00      181
# 15.00      176
# 10.00      165
# 25.00      164
# 30.00      149
# 5.00       145
# 3.00       131
# 40.00      125
# 12.00      121
# 6.00       119
# 2.00       117
# 35.00      111
# 4.00       109
# 8.00       108
# 50.00       97
# 1.00        97
# 7.00        90
# 60.00       88
# 18.00       80
# Name: budget_musd, dtype: int64

# %%
df.revenue_musd.value_counts(dropna = False).head(20)
# Out:
# NaN      13340
# 10.00       15
# 12.00       15
# 2.00        14
# 11.00       13
# 6.00        12
# 5.00        10
# 7.00        10
# 8.00        10
# 20.00        9
# 4.00         8
# 14.00        8
# 0.00         8
# 30.00        7
# 25.00        7
# 3.00         7
# 2.50         7
# 1.00         7
# 9.00         6
# 4.30         6
# Name: revenue_musd, dtype: int64

# %%
df.vote_average.value_counts(dropna = False)
# Out:
# 6.00    902
# 6.50    796
# 7.00    772
# 6.40    762
# 6.30    753
#        ...
# 1.90      1
# 1.20      1
# 8.90      1
# 9.30      1
# 9.20      1
# Name: vote_average, Length: 86, dtype: int64

# %%
df.vote_count.value_counts()
# Out:
# 4.00       684
# 3.00       682
# 2.00       667
# 1.00       589
# 6.00       555
#           ...
# 1833.00      1
# 861.00       1
# 1257.00      1
# 2235.00      1
# 2314.00      1
# Name: vote_count, Length: 1477, dtype: int64

# %%
df.describe(include = "object")
# Out:
#          title                 tagline genres  belongs_to_collection  \
# count    18635                   11161  18285                   2265
# unique   17829                   11133   2472                   1080
# top     Hamlet  Based on a true story.  Drama  James Bond Collection
# freq         7                       4   2032                     24
#
#        original_language       production_companies      production_countries  \
# count              18634                      15608                     17236
# unique                65                      10678                      1300
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               14536                        438                      9240
#
#                                                  overview spoken_languages  \
# count                                               18506            17827
# unique                                              18502             1181
# top     Wilbur the pig is scared of the end of the sea...          English
# freq                                                    2            10340
#
#                                               poster_path         cast  \
# count                                               18605        18191
# unique                                              18605        18162
# top     <img src='http://image.tmdb.org/t/p/w185//uXDf...  Dylan Moran
# freq                                                    1            4
#
#          director
# count       18514
# unique       7080
# top     John Ford
# freq           58

# %% [markdown]
# ## The best and the worst movies.

# %%
from IPython.display import HTML
pd.options.display.max_colwidth = 200

# %%
df_best = df[["poster_path", "title", "budget_musd", "revenue_musd",
              "vote_count", "vote_average", "popularity"]].copy()
df_best.head(1)

# %%
df_best["profit_musd"] = df.revenue_musd.sub(df.budget_musd)
df_best["return"] = df.revenue_musd.div(df.budget_musd)

# %%
df_best.head(1)

# %%
df_best.columns = ["", "Title", "Budget", "Revenue", "Votes",
                   "Average Rating", "Popularity", "Profit", "ROI"]

# %%
df_best.set_index("Title", inplace = True)

# %%
df_best.head(1)

# %%
subset = df_best.iloc[:5, :2]
subset
# Out:
#                                                                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
#
#                              Budget
# Title
# Toy Story                     30.00
# Jumanji                       65.00
# Grumpier Old Men                NaN
# Waiting to Exhale             16.00
# Father of the Bride Part II     NaN

# %%
HTML(subset.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'></td>
#       <td>30.00</td>
#     </tr>
#     <tr>
#       <th>Jumanji</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'></td>
#       <td>65.00</td>
#     </tr>
#     <tr>
#       <th>Grumpier Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Waiting to Exhale</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'></td>
#       <td>16.00</td>
#     </tr>
#     <tr>
#       <th>Father of the Bride Part II</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_best.Budget.fillna(0, inplace = True)
df_best.Votes.fillna(0, inplace = True)

# %%
df_best.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18635 entries, Toy Story to The Dupes
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0                   18605 non-null  object
#  1   Budget          18635 non-null  float64
#  2   Revenue         5295 non-null   float64
#  3   Votes           18635 non-null  float64
#  4   Average Rating  18225 non-null  float64
#  5   Popularity      18634 non-null  float64
#  6   Profit          4018 non-null   float64
#  7   ROI             4018 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 1.3+ MB

# %%
def best_worst(n, by, ascending = False, min_bud = 0, min_votes = 0):


    df2 = df_best.loc[(df_best.Budget >= min_bud) & (df_best.Votes >= min_votes),
                      ["", by]].sort_values(by = by, ascending = ascending).head(n).copy()

    return HTML(df2.to_html(escape=False))

# %% [markdown]
# ## The best and the worst movies.

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
best_worst(n = 5, by = "Revenue")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.97</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.03</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
#       <td>1519.56</td>
#     </tr>
#     <tr>
#       <th>Harry Potter and the Deathly Hallows: Part 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//c54HpQmuwXjHq2C9wmoACjxoom3.jpg' style='height:100px;'></td>
#       <td>1342.00</td>
#     </tr>
#     <tr>
#       <th>Transformers: Dark of the Moon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v0VzOKXpJ1hs09beNbVhDo18Slh.jpg' style='height:100px;'></td>
#       <td>1123.75</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
best_worst(5, "Budget")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//6ZYOpyhFZrAQIe1BuhqVgzfAdGZ.jpg' style='height:100px;'></td>
#       <td>270.00</td>
#     </tr>
#     <tr>
#       <th>Tangled</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1uPxRO0iYwW02lzwatRhkugWBYs.jpg' style='height:100px;'></td>
#       <td>260.00</td>
#     </tr>
#     <tr>
#       <th>John Carter</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7GSSyUUgUEXm1rhmiPGSRuKoqnK.jpg' style='height:100px;'></td>
#       <td>260.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
best_worst(5, "Profit")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2550.97</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1645.03</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
#       <td>1299.56</td>
#     </tr>
#     <tr>
#       <th>Harry Potter and the Deathly Hallows: Part 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//c54HpQmuwXjHq2C9wmoACjxoom3.jpg' style='height:100px;'></td>
#       <td>1217.00</td>
#     </tr>
#     <tr>
#       <th>The Lord of the Rings: The Return of the King</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg' style='height:100px;'></td>
#       <td>1024.89</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
best_worst(5, "Profit", ascending = True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>-119.18</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>-111.01</td>
#     </tr>
#     <tr>
#       <th>The 13th Warrior</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7pyhR5K1iv67daYw0DfsmsersKA.jpg' style='height:100px;'></td>
#       <td>-98.30</td>
#     </tr>
#     <tr>
#       <th>The Adventures of Pluto Nash</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//96vvhLWWDosS1zRrfQ6XEGAzByL.jpg' style='height:100px;'></td>
#       <td>-92.90</td>
#     </tr>
#     <tr>
#       <th>Metropolis</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//3F5OKhpC6rqq5KdjgixNbqjWSWz.jpg' style='height:100px;'></td>
#       <td>-91.97</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
best_worst(5, "ROI", min_bud = 50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Jurassic Park</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oU7Oq2kFAAlGqbU4VoAE36g4hoI.jpg' style='height:100px;'></td>
#       <td>14.60</td>
#     </tr>
#     <tr>
#       <th>The Twilight Saga: New Moon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//j5jM5pq78ObAXX1WhTsb115EkLl.jpg' style='height:100px;'></td>
#       <td>14.20</td>
#     </tr>
#     <tr>
#       <th>Forrest Gump</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//saHP97rTPS5eLmrLQEcANmKrsFl.jpg' style='height:100px;'></td>
#       <td>12.33</td>
#     </tr>
#     <tr>
#       <th>The Lord of the Rings: The Return of the King</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg' style='height:100px;'></td>
#       <td>11.90</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>11.76</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
best_worst(5, "ROI", ascending = True, min_bud = 100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Adventures of Pluto Nash</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//96vvhLWWDosS1zRrfQ6XEGAzByL.jpg' style='height:100px;'></td>
#       <td>0.07</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>0.18</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>0.26</td>
#     </tr>
#     <tr>
#       <th>K-19: The Widowmaker</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ji7YWKx40TM8YexbRqfJZKMhQY3.jpg' style='height:100px;'></td>
#       <td>0.35</td>
#     </tr>
#     <tr>
#       <th>Australia</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//45X7LFsgYvdEgFCkXSZCQOZMuJX.jpg' style='height:100px;'></td>
#       <td>0.38</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
best_worst(5, "Votes")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Votes</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>14075.00</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>12269.00</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>12114.00</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
#       <td>12000.00</td>
#     </tr>
#     <tr>
#       <th>Fight Club</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//bptfVGEQuv6vDTIMVCHjJ9Dz8PX.jpg' style='height:100px;'></td>
#       <td>9678.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
best_worst(5, "Average Rating", min_votes = 50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Dilwale Dulhania Le Jayenge</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2CAL2433ZeIihfX1Hb2139CX0pW.jpg' style='height:100px;'></td>
#       <td>9.10</td>
#     </tr>
#     <tr>
#       <th>Sansho the Bailiff</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//p64ilrhG8DPetzhVk10vuVjAG0t.jpg' style='height:100px;'></td>
#       <td>8.70</td>
#     </tr>
#     <tr>
#       <th>The Godfather</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//iVZ3JAcAjmguGPnRNfWFOtLHOuY.jpg' style='height:100px;'></td>
#       <td>8.50</td>
#     </tr>
#     <tr>
#       <th>The Shawshank Redemption</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5KCVkau1HEl7ZzfPsKAPM0sMiKc.jpg' style='height:100px;'></td>
#       <td>8.50</td>
#     </tr>
#     <tr>
#       <th>Dear Zachary: A Letter to a Son About His Father</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gPMFfxnxM01ujBFsWfWTY9rM2iz.jpg' style='height:100px;'></td>
#       <td>8.40</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
best_worst(5, "Average Rating", ascending = True, min_votes = 100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>House of the Dead</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5jBIUM0tqq8QwNbY8w1RZdU6uWz.jpg' style='height:100px;'></td>
#       <td>2.80</td>
#     </tr>
#     <tr>
#       <th>Dragonball Evolution</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//23PcKOqNdhKeMFzORzQGn5eC44N.jpg' style='height:100px;'></td>
#       <td>2.90</td>
#     </tr>
#     <tr>
#       <th>Battlefield Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wXCRuBHdJ5aTFQdsuGJFXNdo79T.jpg' style='height:100px;'></td>
#       <td>3.00</td>
#     </tr>
#     <tr>
#       <th>Disaster Movie</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//3J8XKUfhJiNzwobUZVtizXYPe8b.jpg' style='height:100px;'></td>
#       <td>3.10</td>
#     </tr>
#     <tr>
#       <th>Alone in the Dark</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tQZbMfQmsUvfoR2nZyqXLOAKzmk.jpg' style='height:100px;'></td>
#       <td>3.10</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_worst(5, "Average Rating", ascending = True, min_votes = 20, min_bud = 20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Dragonball Evolution</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//23PcKOqNdhKeMFzORzQGn5eC44N.jpg' style='height:100px;'></td>
#       <td>2.90</td>
#     </tr>
#     <tr>
#       <th>Battlefield Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wXCRuBHdJ5aTFQdsuGJFXNdo79T.jpg' style='height:100px;'></td>
#       <td>3.00</td>
#     </tr>
#     <tr>
#       <th>Far Cry</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vMIhhBPIM59I7Mik4OofDMvQrlY.jpg' style='height:100px;'></td>
#       <td>3.10</td>
#     </tr>
#     <tr>
#       <th>Disaster Movie</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//3J8XKUfhJiNzwobUZVtizXYPe8b.jpg' style='height:100px;'></td>
#       <td>3.10</td>
#     </tr>
#     <tr>
#       <th>Alone in the Dark</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tQZbMfQmsUvfoR2nZyqXLOAKzmk.jpg' style='height:100px;'></td>
#       <td>3.10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
best_worst(5, "Popularity")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Popularity</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>185.07</td>
#     </tr>
#     <tr>
#       <th>Pulp Fiction</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'></td>
#       <td>140.95</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>123.17</td>
#     </tr>
#     <tr>
#       <th>Blade Runner</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vfzE3pjE5G7G7kcZWrA3fnbZo7V.jpg' style='height:100px;'></td>
#       <td>96.27</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
#       <td>89.89</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (high Rating)__

# %%
df.genres[0]
# Out:
# 'Animation|Comedy|Family'

# %%
mask_genres = df.genres.str.contains("Action") & df.genres.str.contains("Science Fiction")
mask_genres
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18630    False
# 18631    False
# 18632    False
# 18633    False
# 18634    False
# Name: genres, Length: 18635, dtype: bool

# %%
df.cast[0]
# Out:
# 'Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette'

# %%
mask_actor = df.cast.str.contains("Bruce Willis")
mask_actor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18630    False
# 18631    False
# 18632    False
# 18633    False
# 18634      NaN
# Name: cast, Length: 18635, dtype: object

# %%
df.loc[mask_actor & mask_genres, ["title", "vote_average"]].sort_values(by = "vote_average",
                                                                        ascending = False)
# Out:
#                    title  vote_average
# 1448   The Fifth Element          7.30
# 1786          Armageddon          6.50
# 14135         Surrogates          5.90

# %%
bruce = df.loc[mask_actor & mask_genres, ["title", "poster_path", "vote_average"]].sort_values(by = "vote_average", ascending = False).set_index("title")

# %%
HTML(bruce.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Fifth Element</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>7.30</td>
#     </tr>
#     <tr>
#       <th>Armageddon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'></td>
#       <td>6.50</td>
#     </tr>
#     <tr>
#       <th>Surrogates</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v3Z0Hbl0oe57njrrIPh0fJPFoo.jpg' style='height:100px;'></td>
#       <td>5.90</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (low runtime)__

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 18630         Amanda Pope
# 18631          Jsu Garcia
# 18632    J. Searle Dawley
# 18633       Tareque Masud
# 18634                 NaN
# Name: director, Length: 18635, dtype: object

# %%
mask_director = df.director == "Quentin Tarantino"

# %%
mask_actor = df.cast.str.contains("Uma Thurman")

# %%
quentin = df.loc[mask_director & mask_actor,
               ["title", "poster_path", "runtime"]].sort_values(by = "runtime").set_index("title")

# %%
HTML(quentin.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>runtime</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Kill Bill: Vol. 1</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'></td>
#       <td>111.00</td>
#     </tr>
#     <tr>
#       <th>Kill Bill: Vol. 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'></td>
#       <td>136.00</td>
#     </tr>
#     <tr>
#       <th>Pulp Fiction</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'></td>
#       <td>154.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (high Revenue)__

# %%
df.production_companies[1]
# Out:
# 'TriStar Pictures|Teitler Film|Interscope Communications'

# %%
mask_studio = df.production_companies.str.contains("Pixar").fillna(False)

# %%
df.release_date
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 18630   2011-03-18
# 18631   2011-04-10
# 18632   1910-03-18
# 18633   2002-11-08
# 18634   1973-07-01
# Name: release_date, Length: 18635, dtype: datetime64[ns]

# %%
mask_time = df.release_date.between("2010-01-01", "2015-12-31")

# %%
pixar = df.loc[mask_studio & mask_time,
               ["title", "poster_path", "revenue_musd", "release_date"]].sort_values(by = "revenue_musd", ascending = False).set_index("title")

# %%
HTML(pixar.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story 3</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>1066.97</td>
#       <td>2010-06-16</td>
#     </tr>
#     <tr>
#       <th>Cars 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//okIz1HyxeVOMzYwwHUjH2pHi74I.jpg' style='height:100px;'></td>
#       <td>559.85</td>
#       <td>2011-06-11</td>
#     </tr>
#     <tr>
#       <th>Day & Night</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//eQ1QUZfblOrusXVfbzzCuUaM7ix.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#       <td>2010-06-17</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent)__

# %%
mask_genre = df.genres.str.contains("Action") | df.genres.str.contains("Thriller")

# %%
mask_lan = df.original_language == "en"

# %%
mask_vote_av = df.vote_average >= 7.5

# %%
mask_vote_co = df.vote_count >= 10

# %%
next_mov = df.loc[mask_genre & mask_lan & mask_vote_av & mask_vote_co,
               ["title", "poster_path", "genres", "vote_average", "vote_count", "release_date"]].sort_values(by = "release_date", ascending = False).set_index("title").head(20)

# %%
HTML(next_mov.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>genres</th>
#       <th>vote_average</th>
#       <th>vote_count</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Dark Knight Rises</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vzvKcPQ4o7TjWeGIn0aGC9FeVNu.jpg' style='height:100px;'></td>
#       <td>Action|Crime|Drama|Thriller</td>
#       <td>7.60</td>
#       <td>9263.00</td>
#       <td>2012-07-16</td>
#     </tr>
#     <tr>
#       <th>Warrior</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//di8jDHn7N4JgZQzchgxkSILWF6h.jpg' style='height:100px;'></td>
#       <td>Action|Drama</td>
#       <td>7.70</td>
#       <td>1297.00</td>
#       <td>2011-09-09</td>
#     </tr>
#     <tr>
#       <th>Batman: Under the Red Hood</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5GZRRD4Q9kQhyveYU3CFw27sQxi.jpg' style='height:100px;'></td>
#       <td>Action|Animation</td>
#       <td>7.60</td>
#       <td>459.00</td>
#       <td>2010-07-27</td>
#     </tr>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>Action|Thriller|Science Fiction|Mystery|Adventure</td>
#       <td>8.10</td>
#       <td>14075.00</td>
#       <td>2010-07-14</td>
#     </tr>
#     <tr>
#       <th>Shutter Island</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//kve20tXwUZpu4GUX8l6X7Z4jmL6.jpg' style='height:100px;'></td>
#       <td>Drama|Thriller|Mystery</td>
#       <td>7.80</td>
#       <td>6559.00</td>
#       <td>2010-02-18</td>
#     </tr>
#     <tr>
#       <th>Inglourious Basterds</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7sfbEnaARXDDhKm0CZ7D7uc2sbo.jpg' style='height:100px;'></td>
#       <td>Drama|Action|Thriller|War</td>
#       <td>7.90</td>
#       <td>6598.00</td>
#       <td>2009-08-18</td>
#     </tr>
#     <tr>
#       <th>Prison Break: The Final Break</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//h1QRyGuWVXM4Cr3FyPISSjMCBkA.jpg' style='height:100px;'></td>
#       <td>Action|Drama|Thriller</td>
#       <td>7.50</td>
#       <td>174.00</td>
#       <td>2009-05-26</td>
#     </tr>
#     <tr>
#       <th>Man on Wire</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1mS4rhIgHZcHIvf1beP9Av0Ui33.jpg' style='height:100px;'></td>
#       <td>Thriller|Documentary|Crime|History</td>
#       <td>7.50</td>
#       <td>282.00</td>
#       <td>2008-07-25</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>Drama|Action|Crime|Thriller</td>
#       <td>8.30</td>
#       <td>12269.00</td>
#       <td>2008-07-16</td>
#     </tr>
#     <tr>
#       <th>Dr. Horrible's Sing-Along Blog</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//zlAjTMaWakkoJidwsYO0QNwtPqy.jpg' style='height:100px;'></td>
#       <td>Adventure|Action|Comedy|Science Fiction|Music</td>
#       <td>7.80</td>
#       <td>236.00</td>
#       <td>2008-07-15</td>
#     </tr>
#     <tr>
#       <th>No Country for Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//spnMmUIi3AlocdB4XS2MPlN9k0G.jpg' style='height:100px;'></td>
#       <td>Crime|Drama|Thriller</td>
#       <td>7.70</td>
#       <td>3083.00</td>
#       <td>2007-11-08</td>
#     </tr>
#     <tr>
#       <th>Illegal Tender</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5mbWro99ERbipdBQKkYxD3FkSoo.jpg' style='height:100px;'></td>
#       <td>Drama|Action|Thriller|Crime</td>
#       <td>7.60</td>
#       <td>15.00</td>
#       <td>2007-08-24</td>
#     </tr>
#     <tr>
#       <th>Shelter</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//eYA8KiSnIAbxtoIgg4lpZjB0dfz.jpg' style='height:100px;'></td>
#       <td>Action|Drama|Romance</td>
#       <td>7.80</td>
#       <td>100.00</td>
#       <td>2007-06-16</td>
#     </tr>
#     <tr>
#       <th>The Prestige</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//Ag2B2KHKQPukjH7WutmgnnSNurZ.jpg' style='height:100px;'></td>
#       <td>Drama|Mystery|Thriller</td>
#       <td>8.00</td>
#       <td>4510.00</td>
#       <td>2006-10-19</td>
#     </tr>
#     <tr>
#       <th>The Departed</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//p3tmqqwFPHFdu1oVpcgKGfcPCMZ.jpg' style='height:100px;'></td>
#       <td>Drama|Thriller|Crime</td>
#       <td>7.90</td>
#       <td>4455.00</td>
#       <td>2006-10-05</td>
#     </tr>
#     <tr>
#       <th>Cocaine Cowboys</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//hkU1V6DBJoCUxi3xVHiI0OI38oN.jpg' style='height:100px;'></td>
#       <td>Action|Documentary</td>
#       <td>7.50</td>
#       <td>56.00</td>
#       <td>2006-04-26</td>
#     </tr>
#     <tr>
#       <th>V for Vendetta</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2ySXWBckQboalTZjhaLWRqc3gCN.jpg' style='height:100px;'></td>
#       <td>Action|Thriller|Fantasy</td>
#       <td>7.70</td>
#       <td>4562.00</td>
#       <td>2006-03-15</td>
#     </tr>
#     <tr>
#       <th>Batman Begins</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aGdng8Ic4ONpcepU3bVXPSLmNd3.jpg' style='height:100px;'></td>
#       <td>Action|Crime|Drama</td>
#       <td>7.50</td>
#       <td>7511.00</td>
#       <td>2005-06-10</td>
#     </tr>
#     <tr>
#       <th>In My Father's Den</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1D3RT8pQcozWpq6l4qTA9MjJ0vi.jpg' style='height:100px;'></td>
#       <td>Drama|Thriller</td>
#       <td>7.50</td>
#       <td>26.00</td>
#       <td>2004-06-11</td>
#     </tr>
#     <tr>
#       <th>Kill Bill: Vol. 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'></td>
#       <td>Action|Crime|Thriller</td>
#       <td>7.70</td>
#       <td>4061.00</td>
#       <td>2004-04-16</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## What are the most common Words in Movie Titles and Taglines?

# %%
from wordcloud import WordCloud

# %%
df.tagline[1]
# Out:
# 'Roll the dice and unleash the excitement!'

# %%
df.overview[1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures."

# %%
title = df.title.dropna()
overview = df.overview.dropna()
tagline = df.tagline.dropna()

# %%
title
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 18630    The Desert of Forbidden Art
# 18631                  The Wayshower
# 18632                   Frankenstein
# 18633                  The Clay Bird
# 18634                      The Dupes
# Name: title, Length: 18635, dtype: object

# %%
' '.join(title)
# Out:
# 'Toy Story Jumanji Grumpier Old Men Waiting to Exhale Father of the Bride Part II Heat Sabrina Tom and Huck Sudden Death GoldenEye The American President Dracula: Dead and Loving It Balto Nixon Cutthroat Island Casino Sense and Sensibility Four Rooms Ace Ventura: When Nature Calls Money Train Get Shorty Copycat Assassins Powder Leaving Las Vegas Othello Now and Then Persuasion The City of Lost Children Shanghai Triad Dangerous Minds Twelve Monkeys Wings of Courage Babe Carrington Dead Man Walking Across the Sea of Time It Takes Two Clueless Cry, the Beloved Country Richard III Dead Presidents Restoration Mortal Kombat To Die For How To Make An American Quilt Se7en Pocahontas When Night Is Falling The Usual Suspects Guardian Angel Mighty Aphrodite Lamerica The Big Green Georgia Kids of the Round Table Home for the Holidays The Postman The Confessional The Indian in the Cupboard Eye for an Eye Mr. Holland\'s Opus Don\'t Be a Menace to South Central While Drinking Your Juice in the Hood Two If by Sea Bio-Dome Lawnmower Man 2: Beyond Cyberspace Two Bits French Twist Friday From Dusk Till Dawn Fair Game Kicking and Screaming Les Miserables Bed of Roses Big Bully Screamers Nico Icon The Crossing Guard The Juror The White Balloon Things to Do in Denver When You\'re Dead Antonia\'s Line Once Upon a Time... When We Were Colored Last Summer in the Hamptons Angels and Insects White Squall Dunston Checks In Black Sheep Nick of Time The Journey of August King Mary Reilly Vampire in Brooklyn Beautiful Girls Broken Arrow A Midwinter\'s Tale La Haine Shopping Heidi Fleiss: Hollywood Madam City Hall Bottle Rocket Mr. Wrong Unforgettable Happy Gilmore The Bridges of Madison County Nobody Loves Me Muppet Treasure Island Catwalk Headless Body in Topless Bar Braveheart Taxi Driver Rumble in the Bronx Before and After Margaret\'s Museum Happiness Is in the Field Anne Frank Remembered The Young Poisoner\'s Handbook If Lucy Fell Steal Big Steal Little Race the Sun The Boys of St. Vincent Boomerang Chungking Express The Star Maker Flirting with Disaster The Neverending Story III: Escape from Fantasia The Silences of the Palace Jupiter\'s Wife Pie in the Sky Angela Frankie Starlight Jade Nueba Yol Sonic Outlaws Down Periscope From the Journals of Jean Seberg Man of the Year The Neon Bible Target Up Close & Personal The Birdcage Virgin Mary The Brothers McMullen Bad Boys The Amazing Panda Adventure The Basketball Diaries An Awfully Big Adventure Amateur Apollo 13 Rob Roy The Addiction Batman Forever Belle de Jour Beyond Rangoon Blue in the Face Canadian Bacon Casper Clockers Congo Crimson Tide Crumb Desperado Devil in a Blue Dress Die Hard: With a Vengeance The Doom Generation Feast of July First Knight Free Willy 2 - The Adventure Home Hackers Jeffrey Johnny Mnemonic Judge Dredd Jury Duty Kids Living in Oblivion Lord of Illusions Love & Human Remains Mad Love Mallrats Mighty Morphin Power Rangers: The Movie Moonlight and Valentino Mute Witness Nadja The Net Nine Months Party Girl The Prophecy Reckless Safe The Scarlet Letter Showgirls Smoke Something to Talk About Species The Stars Fell on Henrietta Strange Days The Umbrellas of Cherbourg The Tie That Binds Three Wishes Total Eclipse To Wong Foo, Thanks for Everything! Julie Newmar Under Siege 2: Dark Territory Unstrung Heroes Unzipped A Walk in the Clouds Waterworld White Man\'s Burden Wild Bill The Browning Version Bushwhacked Burnt by the Sun Before the Rain Before Sunrise Billy Madison The Babysitter Boys on the Side The Cure Castle Freak Circle of Friends Clerks Don Juan DeMarco Disclosure Dream Man Drop Zone Destiny Turns on the Radio Death and the Maiden Dolores Claiborne Dumb and Dumber Eat Drink Man Woman Exotica Exit to Eden Ed Wood French Kiss Forget Paris Far from Home: The Adventures of Yellow Dog A Goofy Movie Hideaway Fluke Farinelli Gordy Gumby: The Movie The Glass Shield Hoop Dreams Heavenly Creatures Houseguest Immortal Beloved Heavyweights The Hunted I.Q. Interview with the Vampire J ...

# %%
title_corpus = ' '.join(title)
overview_corpus = ' '.join(overview)
tagline_corpus = ' '.join(tagline)

# %%
tagline_corpus
# Out:
# 'Roll the dice and unleash the excitement! Still Yelling. Still Fighting. Still Ready for Love. Friends are the people who let you be yourself... and never let you forget it. Just When His World Is Back To Normal... He\'s In For The Surprise Of His Life! A Los Angeles Crime Saga You are cordially invited to the most surprising merger of the year. The Original Bad Boys. Terror goes into overtime. No limits. No fears. No substitutes. Why can\'t the most powerful man in the world have the one thing he wants most? Part Dog. Part Wolf. All Hero. Triumphant in Victory, Bitter in Defeat. He Changed the World, But Lost a Nation. The Course Has Been Set. There Is No Turning Back. Prepare Your Weapons. Summon Your Courage. Discover the Adventure of a Lifetime! No one stays at the top forever. Lose your heart and come to your senses. Twelve outrageous guests. Four scandalous requests. And one lone bellhop, in his first day on the job, who\'s in for the wildest New year\'s Eve of his life. New animals. New adventures. Same hair. Get on, or GET OUT THE WAY! The mob is tough, but it’s nothing like show business. One man is copying the most notorious killers in history one at a time. Together, two women must stop him from killing again. Or they\'re next. In the shadows of life, In the business of death, One man found a reason to live... An extraordinary encounter with another human being. I Love You... The Way You Are. Envy, greed, jealousy and love. In every woman there is the girl she left behind. Where happily ever after is just a dream. In 1930\'s Shanghai violence was not the problem. It was the solution. She broke the rules... and changed their lives. The future is history. A little pig goes a long way. A Love so Unusual it has to be True Two identical strangers. Two different worlds. One perfect match. Sex. Clothes. Popularity. Is there a problem here? I can smile, and murder while I smile In this daring heist, the only color that counts is green Nothing In This World Has Prepared You For This. All she wanted was a little attention. There\'s beauty in the patterns of life. Seven deadly sins. Seven ways to die. An American legend comes to life. Five Criminals. One Line Up. No Coincidence. She\'s no angel of mercy. The biggest kick of the year! The toughest act to follow was their dreams. We\'ll do it every year..until we get it right What do you do when justice fails? Of All the Lives He Changed, the One That Changed the Most Was His Own. Finally, the movie that proves that Justice isn\'t always Poetic, Jungle Fever isn\'t always pretty, and Higher Learning can be a waste of time. A new comedy about love, laughter, and larceny Bud and Doyle are here to save the world. But who\'s gonna save the world from Bud and Doyle? God made him simple. Science made him a god. Now, he wants revenge. You\'re never too old to believe in a dream. Or too young to make one come true! A lot can go down between thursday and saturday... One night is all that stands between them and freedom. But it\'s going to be a hell of a night. He\'s a cop on the edge. She\'s a woman with a dangerous secret. And now they\'re both... Anxiety loves company. In a time of chaos, in a world of change, he was moved by a book he could not read to become a hero he never imagined. He gave her flowers. She gave him a chance. A comedy for the kid in all of us. The last scream you hear will be your own. ...some lives cross, others collide. There is no defense. Protect. Love. Honor. Avenge. A motion picture that celebrates everything you love about life. An elegant seduction. An erotic deception. A stunning revelation. He\'s about to turn a Five Star Hotel into a three ring circus. There\'s one in every family. The untold story of Jekyll and Hyde A comic tale of horror and seduction. Good times never seemed so good, Prepare to Go Ballistic. The drama. The passion. The intrigue... And the rehearsals haven\'t even started. Three Young Friends... One Last Chance. No one leaves without p ...

# %%
title_wordcloud = WordCloud(background_color='white', height=2000, width=4000, max_words= 200).generate(title_corpus)
title_wordcloud

# %%
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud, interpolation= "bilinear")
plt.axis('off')
plt.show()

# %%
tagline_wordcloud = WordCloud(background_color='white', height=2000, width=4000).generate(tagline_corpus)
plt.figure(figsize=(16,8))
plt.imshow(tagline_wordcloud, interpolation= "bilinear")
plt.axis('off')
plt.show()

# %%
overview_wordcloud = WordCloud(background_color='white', height=2000, width=4000).generate(overview_corpus)
plt.figure(figsize=(16,8))
plt.imshow(overview_wordcloud, interpolation= "bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Are Franchises more successful?

# %%
df.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 18630                               NaN
# 18631                               NaN
# 18632                               NaN
# 18633                               NaN
# 18634                               NaN
# Name: belongs_to_collection, Length: 18635, dtype: object

# %%
df["Franchise"] = df.belongs_to_collection.notna()

# %%
df.Franchise
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 18630    False
# 18631    False
# 18632    False
# 18633    False
# 18634    False
# Name: Franchise, Length: 18635, dtype: bool

# %%
df.Franchise.value_counts()
# Out:
# False    16370
# True      2265
# Name: Franchise, dtype: int64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
df.groupby("Franchise").revenue_musd.mean()
# Out:
# Franchise
# False    46.38
# True    146.07
# Name: revenue_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability__

# %%
df["ROI"] = df.revenue_musd.div(df.budget_musd)

# %%
df.groupby("Franchise").ROI.median()
# Out:
# Franchise
# False   1.62
# True    3.77
# Name: ROI, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
df.groupby("Franchise").budget_musd.mean()
# Out:
# Franchise
# False   21.33
# True    35.29
# Name: budget_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
df.groupby("Franchise").popularity.mean()
# Out:
# Franchise
# False   3.73
# True    7.57
# Name: popularity, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
df.groupby("Franchise").vote_average.mean()
# Out:
# Franchise
# False   6.20
# True    6.08
# Name: vote_average, dtype: float64

# %%
df.groupby("Franchise").agg({"budget_musd": "mean", "revenue_musd": "mean", "vote_average": "mean",
                            "popularity": "mean", "ROI":"median", "vote_count":"mean"})
# Out:
#            budget_musd  revenue_musd  vote_average  popularity  ROI  \
# Franchise
# False            21.33         46.38          6.20        3.73 1.62
# True             35.29        146.07          6.08        7.57 3.77
#
#            vote_count
# Franchise
# False          117.92
# True           549.96

# %% [markdown]
# ## Most Successful Franchises

# %%
df.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 18630                               NaN
# 18631                               NaN
# 18632                               NaN
# 18633                               NaN
# 18634                               NaN
# Name: belongs_to_collection, Length: 18635, dtype: object

# %%
df.belongs_to_collection.value_counts()
# Out:
# James Bond Collection            24
# Godzilla (Showa) Collection      14
# Friday the 13th Collection       12
# Sherlock Holmes (1939 series)    10
# Ernest Collection                 9
#                                  ..
# Father Flanagan Collection        1
# Appleseed Collection              1
# Brancaleone Collection            1
# The Yakuza Papers Collection      1
# The Raid Collection               1
# Name: belongs_to_collection, Length: 1080, dtype: int64

# %%
franchises = df.groupby("belongs_to_collection").agg({"title":"count", "budget_musd": ["sum", "mean"],
                                                      "revenue_musd": ["sum", "mean"],
                                                      "vote_average": "mean", "popularity": "mean",
                                                      "ROI":"median",
                                                      "vote_count":"mean"})

# %%
franchises
# Out:
#                                         title budget_musd       revenue_musd  \
#                                         count         sum  mean          sum
# belongs_to_collection
# 100 Girls Collection                        1        0.00   NaN         0.00
# 101 Dalmatians (Animated) Collection        1        4.00  4.00       215.88
# 101 Dalmatians (Live-Action) Collection     2      139.00 69.50       504.30
# 12 Rounds Collection                        1       20.00 20.00        17.28
# 2 Days In... Collection                     1        0.00   NaN        19.78
# ...                                       ...         ...   ...          ...
# Zu Warriors Collection                      1        0.00   NaN         0.00
# [REC] Collection                            2        7.10  3.55        48.92
# xXx Collection                              2      130.00 65.00       348.52
# Ирония судьбы (Коллекция)                   1        0.00   NaN         0.00
# 男はつらいよ シリーズ                                 3        0.00   NaN         0.00
#
#                                                vote_average popularity    ROI  \
#                                           mean         mean       mean median
# belongs_to_collection
# 100 Girls Collection                       NaN         5.60       5.14    NaN
# 101 Dalmatians (Animated) Collection    215.88         6.80      15.73  53.97
# 101 Dalmatians (Live-Action) Collection 252.15         5.35       9.57   4.05
# 12 Rounds Collection                     17.28         5.70      13.59   0.86
# 2 Days In... Collection                  19.78         6.30       6.65    NaN
# ...                                        ...          ...        ...    ...
# Zu Warriors Collection                     NaN         6.60       1.40    NaN
# [REC] Collection                         24.46         6.80       8.68  11.80
# xXx Collection                          174.26         5.25      15.93   2.57
# Ирония судьбы (Коллекция)                  NaN         7.20       2.69    NaN
# 男はつらいよ シリーズ                                NaN         7.00       0.04    NaN
#
#                                         vote_count
#                                               mean
# belongs_to_collection
# 100 Girls Collection                        119.00
# 101 Dalmatians (Animated) Collection       1643.00
# 101 Dalmatians (Live-Action) Collection     524.50
# 12 Rounds Collection                        223.00
# 2 Days In... Collection                     106.00
# ...                                            ...
# Zu Warriors Collection                       14.00
# [REC] Collection                            725.00
# xXx Collection                             1009.50
# Ирония судьбы (Коллекция)                    36.00
# 男はつらいよ シリーズ                                   0.67
#
# [1080 rows x 9 columns]

# %%
franchises.nlargest(20, ("title", "count"))
# Out:
#                                           title budget_musd         \
#                                           count         sum   mean
# belongs_to_collection
# James Bond Collection                        24     1094.65  45.61
# Godzilla (Showa) Collection                  14        2.05   0.51
# Friday the 13th Collection                   12       84.40   7.03
# Sherlock Holmes (1939 series)                10        0.00    NaN
# Ernest Collection                             9        9.00   4.50
# The Pink Panther (Original) Collection        9       47.00  11.75
# A Nightmare on Elm Street Collection          8       84.80  10.60
# Asterix and Obelix (Animation) Collection     8        0.00    NaN
# Dracula (Hammer Series)                       8        0.98   0.33
# Halloween Collection                          8       50.30   6.29
# Harry Potter Collection                       8     1280.00 160.00
# Hellraiser Collection                         8       27.00   3.38
# Puppet Master Collection                      8        1.58   0.79
# The Amityville Horror Collection              8       20.50  10.25
# Babylon 5 Collection                          7        0.00    NaN
# Police Academy Collection                     7        4.50   4.50
# Road to Collection                            7        0.00    NaN
# Saw Collection                                7       67.00   9.57
# Why We Fight                                  7        0.00    NaN
# Cheech & Chong Collection                     6        0.00    NaN
#
#                                           revenue_musd        vote_average  \
#                                                    sum   mean         mean
# belongs_to_collection
# James Bond Collection                          5117.73 213.24         6.32
# Godzilla (Showa) Collection                       0.00    NaN         6.03
# Friday the 13th Collection                      464.90  38.74         5.42
# Sherlock Holmes (1939 series)                     0.00    NaN         6.97
# Ernest Collection                                51.71  25.86         4.51
# The Pink Panther (Original) Collection          164.48  20.56         5.60
# A Nightmare on Elm Street Collection            363.59  45.45         5.96
# Asterix and Obelix (Animation) Collection         0.00    NaN         6.59
# Dracula (Hammer Series)                           0.91   0.45         6.15
# Halloween Collection                            247.17  30.90         5.65
# Harry Potter Collection                        7707.37 963.42         7.54
# Hellraiser Collection                            55.86  13.97         5.24
# Puppet Master Collection                          0.00    NaN         4.33
# The Amityville Horror Collection                213.35  53.34         4.40
# Babylon 5 Collection                              0.00    NaN         6.49
# Police Academy Collection                       304.64  43.52         5.14
# Road to Collection                                0.00    NaN         6.49
# Saw Collection                                  878.31 125.47         6.19
# Why We Fight                                      0.00    NaN         5.59
# Cheech & Chong Collection                       119.94  29.99         6.05
#
#                                           popularity    ROI vote_count
#                                                 mean median       mean
# belongs_to_collection
# James Bond Collection                          12.69   6.50     880.08
# Godzilla (Showa) Collection                     3.61    NaN      41.64
# Friday the 13th Collection                      9.76   6.67     326.58
# Sherlock Holmes (1939 series)                   3.02    NaN      22.70
# Ernest Collection                               2.20   6.27      23.11
# The Pink Panther (Original) Collection          6.00   3.02     100.00
# A Nightmare on Elm Street Collection            9.98   6.13     478.50
# Asterix and Obelix (Animation) Collection       6.99    NaN     158.25
# Dracula (Hammer Series)                         5.56   1.30      49.38
# Halloween Collection                            8.99   3.40     347.00
# Harry Potter Collection                        26.25   6.17    5983.25
# Hellraiser Collection                           6.71   4.10     159.25
# Puppet Master Collection                        3.10    NaN      27.00
# The Amityville Horror Collection                7.59   5.69     121.38
# Babylon 5 Collection                            5.05    NaN      37.57
# Police Academy Collection                       7.50  32.49     291.29
# Road to Collection                              1.69    NaN      13.43
# Saw Collection                                 15.75  13.94    1135.14
# Why We Fight                                    0.34    NaN       1.86
# Cheech & Chong Collection                       6.96    NaN      65.33

# %%
franchises.nlargest(20, ("revenue_musd", "mean"))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# Avatar Collection                       1      237.00 237.00      2787.97
# The Avengers Collection                 1      220.00 220.00      1519.56
# Alice in Wonderland Collection          1      200.00 200.00      1025.49
# The Lord of the Rings Collection        3      266.00  88.67      2916.54
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# Finding Nemo Collection                 1       94.00  94.00       940.34
# Pirates of the Caribbean Collection     4     1020.00 255.00      3727.38
# Transformers Collection                 3      495.00 165.00      2669.75
# Spider-Man Collection                   3      597.00 199.00      2496.35
# The Dark Knight Collection              3      585.00 195.00      2463.72
# Independence Day Collection             1       75.00  75.00       816.97
# The Lion King Collection                3       45.00  45.00       788.24
# Shrek Collection                        5      535.00 133.75      2955.81
# Star Wars Collection                    6      409.35  68.23      4310.21
# The Hunger Games Collection             1       75.00  75.00       691.21
# Kung Fu Panda Collection                2      280.00 140.00      1297.44
# Toy Story Collection                    3      320.00 106.67      1937.89
# Ice Age Collection                      3      229.00  76.33      1930.88
# The Incredibles Collection              1       92.00  92.00       631.44
# The Twilight Collection                 4      265.00  66.25      2513.11
#
#                                             vote_average popularity    ROI  \
#                                        mean         mean       mean median
# belongs_to_collection
# Avatar Collection                   2787.97         7.20     185.07  11.76
# The Avengers Collection             1519.56         7.40      89.89   6.91
# Alice in Wonderland Collection      1025.49         6.40      17.29   5.13
# The Lord of the Rings Collection     972.18         8.03      30.27  11.73
# Harry Potter Collection              963.42         7.54      26.25   6.17
# Finding Nemo Collection              940.34         7.60      25.50  10.00
# Pirates of the Caribbean Collection  931.85         6.95      34.01   3.94
# Transformers Collection              889.92         6.23       4.81   5.58
# Spider-Man Collection                832.12         6.47      22.62   3.92
# The Dark Knight Collection           821.24         7.80      57.42   4.34
# Independence Day Collection          816.97         6.70      17.63  10.89
# The Lion King Collection             788.24         7.00      13.32  17.52
# Shrek Collection                     738.95         6.46      12.97   5.56
# Star Wars Collection                 718.37         7.35      19.85  12.87
# The Hunger Games Collection          691.21         6.90      20.03   9.22
# Kung Fu Panda Collection             648.72         6.80      14.19   4.65
# Toy Story Collection                 645.96         7.53      18.82   5.53
# Ice Age Collection                   643.63         6.70      15.65   8.26
# The Incredibles Collection           631.44         7.40      22.22   6.86
# The Twilight Collection              628.28         5.78      30.36  10.44
#
#                                     vote_count
#                                           mean
# belongs_to_collection
# Avatar Collection                     12114.00
# The Avengers Collection               12000.00
# Alice in Wonderland Collection         4773.00
# The Lord of the Rings Collection       8253.00
# Harry Potter Collection                5983.25
# Finding Nemo Collection                6292.00
# Pirates of the Caribbean Collection    5566.50
# Transformers Collection                3552.00
# Spider-Man Collection                  4505.67
# The Dark Knight Collection             9681.00
# Independence Day Collection            3334.00
# The Lion King Collection               2416.00
# Shrek Collection                       2344.20
# Star Wars Collection                   5056.50
# The Hunger Games Collection            9634.00
# Kung Fu Panda Collection               2578.00
# Toy Story Collection                   4679.67
# Ice Age Collection                     3106.00
# The Incredibles Collection             5290.00
# The Twilight Collection                2802.50

# %%
franchises.nlargest(20, ("budget_musd", "mean"))
# Out:
#                                         title budget_musd        revenue_musd  \
#                                         count         sum   mean          sum
# belongs_to_collection
# Tangled Collection                          1      260.00 260.00       591.79
# Pirates of the Caribbean Collection         4     1020.00 255.00      3727.38
# Avatar Collection                           1      237.00 237.00      2787.97
# The Avengers Collection                     1      220.00 220.00      1519.56
# Alice in Wonderland Collection              1      200.00 200.00      1025.49
# Spider-Man Collection                       3      597.00 199.00      2496.35
# The Dark Knight Collection                  3      585.00 195.00      2463.72
# The Chronicles of Narnia Collection         3      560.00 186.67      1584.14
# G.I. Joe (Live-Action) Collection           1      175.00 175.00       302.47
# Iron Man Collection                         2      340.00 170.00      1209.11
# How to Train Your Dragon Collection         1      165.00 165.00       494.88
# Transformers Collection                     3      495.00 165.00      2669.75
# Cars Collection                             2      320.00 160.00      1021.84
# Harry Potter Collection                     8     1280.00 160.00      7707.37
# Van Helsing Collection                      1      160.00 160.00       300.26
# Star Trek: Alternate Reality Collection     1      150.00 150.00       385.68
# Tarzan (Animation) Collection               1      150.00 150.00       448.00
# The Wolverine Collection                    1      150.00 150.00       373.06
# Thor Collection                             1      150.00 150.00       449.33
# Captain America Collection                  1      140.00 140.00       370.57
#
#                                                 vote_average popularity  \
#                                            mean         mean       mean
# belongs_to_collection
# Tangled Collection                       591.79         7.40      14.68
# Pirates of the Caribbean Collection      931.85         6.95      34.01
# Avatar Collection                       2787.97         7.20     185.07
# The Avengers Collection                 1519.56         7.40      89.89
# Alice in Wonderland Collection          1025.49         6.40      17.29
# Spider-Man Collection                    832.12         6.47      22.62
# The Dark Knight Collection               821.24         7.80      57.42
# The Chronicles of Narnia Collection      528.05         6.40      14.34
# G.I. Joe (Live-Action) Collection        302.47         5.60      11.79
# Iron Man Collection                      604.55         7.00      20.58
# How to Train Your Dragon Collection      494.88         7.50      14.42
# Transformers Collection                  889.92         6.23       4.81
# Cars Collection                          510.92         6.20      16.30
# Harry Potter Collection                  963.42         7.54      26.25
# Van Helsing Collection                   300.26         6.00      12.64
# Star Trek: Alternate Reality Collection  385.68         7.40      15.36
# Tarzan (Animation) Collection            448.00         7.10      12.45
# The Wolverine Collection                 373.06         6.20       1.46
# Thor Collection                          449.33         6.60      29.16
# Captain America Collection               370.57         6.60      19.32
#
#                                            ROI vote_count
#                                         median       mean
# belongs_to_collection
# Tangled Collection                        2.28    3419.00
# Pirates of the Caribbean Collection       3.94    5566.50
# Avatar Collection                        11.76   12114.00
# The Avengers Collection                   6.91   12000.00
# Alice in Wonderland Collection            5.13    4773.00
# Spider-Man Collection                     3.92    4505.67
# The Dark Knight Collection                4.34    9681.00
# The Chronicles of Narnia Collection       2.68    1977.33
# G.I. Joe (Live-Action) Collection         1.73    1988.00
# Iron Man Collection                       3.65    7960.00
# How to Train Your Dragon Collection       3.00    4319.00
# Transformers Collection                   5.58    3552.00
# Cars Collection                           3.32    3039.50
# Harry Potter Collection                   6.17    5983.25
# Van Helsing Collection                    1.88    1674.00
# Star Trek: Alternate Reality Collection   2.57    4574.00
# Tarzan (Animation) Collection             2.99    1715.00
# The Wolverine Collection                  2.49    4086.00
# Thor Collection                           3.00    6678.00
# Captain America Collection                2.65    7174.00

# %%
franchises[franchises[("vote_count", "mean")] >=1000].nlargest(20, ("vote_average", "mean"))
# Out:
#                                         title budget_musd        revenue_musd  \
#                                         count         sum   mean          sum
# belongs_to_collection
# The Lord of the Rings Collection            3      266.00  88.67      2916.54
# The Godfather Collection                    3       73.00  24.33       429.38
# Blade Runner Collection                     1       28.00  28.00        33.14
# The Man With No Name Collection             3        2.00   0.67        35.50
# The Dark Knight Collection                  3      585.00 195.00      2463.72
# Trainspotting Collection                    1        4.00   4.00        16.49
# Kill Bill Collection                        2       60.00  30.00       333.11
# Finding Nemo Collection                     1       94.00  94.00       940.34
# Mulan Collection                            1       90.00  90.00       304.32
# Harry Potter Collection                     8     1280.00 160.00      7707.37
# Toy Story Collection                        3      320.00 106.67      1937.89
# Back to the Future Collection               3       99.00  33.00       957.64
# Beauty and the Beast Collection             1       25.00  25.00       377.35
# How to Train Your Dragon Collection         1      165.00 165.00       494.88
# Star Trek: Alternate Reality Collection     1      150.00 150.00       385.68
# Tangled Collection                          1      260.00 260.00       591.79
# The Avengers Collection                     1      220.00 220.00      1519.56
# The Incredibles Collection                  1       92.00  92.00       631.44
# Star Wars Collection                        6      409.35  68.23      4310.21
# The Raid Collection                         1        1.10   1.10         4.11
#
#                                                 vote_average popularity  \
#                                            mean         mean       mean
# belongs_to_collection
# The Lord of the Rings Collection         972.18         8.03      30.27
# The Godfather Collection                 143.13         7.97      31.64
# Blade Runner Collection                   33.14         7.90      96.27
# The Man With No Name Collection           11.83         7.83      14.17
# The Dark Knight Collection               821.24         7.80      57.42
# Trainspotting Collection                  16.49         7.80      19.35
# Kill Bill Collection                     166.55         7.70      23.40
# Finding Nemo Collection                  940.34         7.60      25.50
# Mulan Collection                         304.32         7.60      21.18
# Harry Potter Collection                  963.42         7.54      26.25
# Toy Story Collection                     645.96         7.53      18.82
# Back to the Future Collection            319.21         7.50      17.50
# Beauty and the Beast Collection          377.35         7.50      23.43
# How to Train Your Dragon Collection      494.88         7.50      14.42
# Star Trek: Alternate Reality Collection  385.68         7.40      15.36
# Tangled Collection                       591.79         7.40      14.68
# The Avengers Collection                 1519.56         7.40      89.89
# The Incredibles Collection               631.44         7.40      22.22
# Star Wars Collection                     718.37         7.35      19.85
# The Raid Collection                        4.11         7.30      10.53
#
#                                            ROI vote_count
#                                         median       mean
# belongs_to_collection
# The Lord of the Rings Collection         11.73    8253.00
# The Godfather Collection                  3.66    3677.00
# Blade Runner Collection                   1.18    3833.00
# The Man With No Name Collection          25.00    1422.67
# The Dark Knight Collection                4.34    9681.00
# Trainspotting Collection                  4.12    2737.00
# Kill Bill Collection                      5.55    4576.00
# Finding Nemo Collection                  10.00    6292.00
# Mulan Collection                          3.38    2089.00
# Harry Potter Collection                   6.17    5983.25
# Toy Story Collection                      5.53    4679.67
# Back to the Future Collection             8.30    4381.00
# Beauty and the Beast Collection          15.09    3029.00
# How to Train Your Dragon Collection       3.00    4319.00
# Star Trek: Alternate Reality Collection   2.57    4574.00
# Tangled Collection                        2.28    3419.00
# The Avengers Collection                   6.91   12000.00
# The Incredibles Collection                6.86    5290.00
# Star Wars Collection                     12.87    5056.50
# The Raid Collection                       3.73    1076.00

# %% [markdown]
# ## Most Successful Directors

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 18630         Amanda Pope
# 18631          Jsu Garcia
# 18632    J. Searle Dawley
# 18633       Tareque Masud
# 18634                 NaN
# Name: director, Length: 18635, dtype: object

# %%
df.director.value_counts().head(20)
# Out:
# John Ford            58
# Alfred Hitchcock     52
# Michael Curtiz       43
# Woody Allen          43
# Fritz Lang           38
# Ingmar Bergman       35
# Robert Altman        35
# John Huston          33
# Sidney Lumet         33
# Jean-Luc Godard      33
# Martin Scorsese      32
# Werner Herzog        32
# Clint Eastwood       32
# Howard Hawks         31
# George Cukor         31
# Akira Kurosawa       30
# Blake Edwards        29
# Buster Keaton        29
# Vincente Minnelli    29
# Steven Spielberg     28
# Name: director, dtype: int64

# %%
plt.figure(figsize = (12, 8))
df.director.value_counts().head(20).plot(kind='bar', fontsize = 15)
plt.title("Most Active Directors",fontsize = 20)
plt.ylabel("Number of Movies", fontsize = 15)
plt.show()

# %%
df.groupby("director").revenue_musd.sum().nlargest(20)
# Out:
# director
# Steven Spielberg     8632.50
# James Cameron        5900.61
# Michael Bay          4585.53
# David Yates          4168.48
# Robert Zemeckis      3795.76
# Chris Columbus       3623.20
# Peter Jackson        3592.72
# Christopher Nolan    3552.41
# Gore Verbinski       3459.49
# Tim Burton           3426.73
# George Lucas         3341.55
# Ron Howard           3310.06
# Roland Emmerich      3203.17
# Sam Raimi            2701.92
# Andrew Adamson       2572.71
# Ridley Scott         2312.78
# John Lasseter        2256.02
# Clint Eastwood       2252.55
# Tony Scott           2129.61
# M. Night Shyamalan   2110.06
# Name: revenue_musd, dtype: float64

# %%
plt.figure(figsize = (12, 8))
df.groupby("director").revenue_musd.sum().nlargest(20).plot(kind='bar', fontsize = 15)
plt.title("Total Revenue",fontsize = 20)
plt.ylabel("Revenue (in MUSD)", fontsize = 15)
plt.show()

# %%
directors = df.groupby("director").agg({"title": "count", "vote_average" :"mean", "vote_count": "sum"})

# %%
directors
# Out:
#                       title  vote_average  vote_count
# director
# 50 Cent                   1          4.70        6.00
# A. Dean Bell              1          6.10        4.00
# A. Edward Sutherland      4          4.40       37.00
# A.R. Murugadoss           1          6.90       84.00
# A.W. Vidmer               1         10.00        1.00
# ...                     ...           ...         ...
# Éva Gárdos                1          6.00       14.00
# Ömer Faruk Sorak          1          7.40       43.00
# Özer Kiziltan             1          7.70       13.00
# Özhan Eren                1          7.50        2.00
# Šarūnas Bartas            5          6.44       16.00
#
# [7080 rows x 3 columns]

# %%
directors[(directors.vote_count >= 10000) & (directors.title >= 10)].nlargest(20, "vote_average")
# Out:
#                       title  vote_average  vote_count
# director
# Hayao Miyazaki           10          7.84    13927.00
# Stanley Kubrick          13          7.42    18154.00
# Martin Scorsese          32          7.22    27922.00
# Peter Jackson            10          7.11    29627.00
# Joel Coen                15          7.10    15956.00
# Steven Spielberg         28          6.99    57137.00
# James Cameron            10          6.92    33707.00
# Tim Burton               15          6.90    29038.00
# Robert Zemeckis          15          6.87    32650.00
# Luc Besson               10          6.77    10786.00
# Ridley Scott             19          6.75    25131.00
# Woody Allen              43          6.74    11620.00
# Danny Boyle              10          6.73    13111.00
# Alfred Hitchcock         52          6.66    12759.00
# Clint Eastwood           32          6.65    17038.00
# Sam Raimi                13          6.54    18365.00
# Brian De Palma           24          6.51    11361.00
# Richard Donner           17          6.51    10234.00
# Francis Ford Coppola     22          6.50    16187.00
# Chris Columbus           14          6.50    23849.00

# %%
df.genres = df.genres.astype(str)

# %%
df.loc[df.genres.str.contains("Horror")].groupby("director").revenue_musd.sum().nlargest(20)
# Out:
# director
# Wes Craven             834.93
# Francis Lawrence       816.23
# Steven Spielberg       500.10
# William Friedkin       466.40
# Ridley Scott           456.62
# Darren Lynn Bousman    456.34
# Paul W.S. Anderson     429.89
# David R. Ellis         348.74
# Adrian Lyne            346.11
# Stephen Sommers        311.46
# Gore Verbinski         249.35
# Joe Dante              249.15
# Daniel Myrick          248.00
# Peter Hyams            245.95
# Neil Jordan            231.06
# Mark Steven Johnson    228.74
# Alexandre Aja          225.25
# James Wan              223.14
# Takashi Shimizu        222.62
# Francis Ford Coppola   215.86
# Name: revenue_musd, dtype: float64

# %% [markdown]
# ## Most Successful Actors (Part 1)

# %%
df.cast
# Out:
# 0                                     Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette
# 1        Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyru...
# 2                                                                                                                 Walter Matthau|Jack Lemmon|Ann-Margret|Sophia Loren|Daryl Hannah|Burgess Meredith|Kevin Pollak
# 3                                                          Whitney Houston|Angela Bassett|Loretta Devine|Lela Rochon|Gregory Hines|Dennis Haysbert|Michael Beach|Mykelti Williamson|Lamont Johnson|Wesley Snipes
# 4                               Steve Martin|Diane Keaton|Martin Short|Kimberly Williams-Paisley|George Newbern|Kieran Culkin|BD Wong|Peter Michael Goetz|Kate McGregor-Stewart|Jane Adams|Eugene Levy|Lori Alan
#                                                                                                           ...
# 18630                                                                                                                                                                          Ed Asner|Sally Field|Ben Kingsley
# 18631    Eric Roberts|Peter Stormare|Sally Kirkland|Jsu Garcia|Howard Lazar|Sara Malakul Lane|Rick Ojeda|Sebastian Michael Barr|Nina Bergman|Matthew Albert Cole|Bill Cox|Claudia Craciun|Brandyn Cross|Laura...
# 18632                                                                                                                                                                 Mary Fuller|Charles Ogle|Augustus Phillips
# 18633                                                                                                                                       Nurul Islam Bablu|Russell Farazi|Jayanto Chattopadhyay|Rokeya Prachy
# 18634                                                                                                                                                                                                        NaN
# Name: cast, Length: 18635, dtype: object

# %%
df.head()

# %%
df.set_index("id", inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18635 entries, 862 to 178535
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  18635 non-null  object
#  1   tagline                11161 non-null  object
#  2   release_date           18631 non-null  datetime64[ns]
#  3   genres                 18635 non-null  object
#  4   belongs_to_collection  2265 non-null   object
#  5   original_language      18634 non-null  object
#  6   budget_musd            5661 non-null   float64
#  7   revenue_musd           5295 non-null   float64
#  8   production_companies   15608 non-null  object
#  9   production_countries   17236 non-null  object
#  10  vote_count             18634 non-null  float64
#  11  vote_average           18225 non-null  float64
#  12  popularity             18634 non-null  float64
#  13  runtime                18440 non-null  float64
#  14  overview               18506 non-null  object
#  15  spoken_languages       17827 non-null  object
#  16  poster_path            18605 non-null  object
#  17  cast                   18191 non-null  object
#  18  cast_size              18634 non-null  float64
#  19  crew_size              18634 non-null  float64
#  20  director               18514 non-null  object
#  21  Franchise              18635 non-null  bool
#  22  ROI                    4018 non-null   float64
# dtypes: bool(1), datetime64[ns](1), float64(9), object(12)
# memory usage: 3.3+ MB

# %%
df.cast
# Out:
# id
# 862                                    Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette
# 8844      Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyru...
# 15602                                                                                                              Walter Matthau|Jack Lemmon|Ann-Margret|Sophia Loren|Daryl Hannah|Burgess Meredith|Kevin Pollak
# 31357                                                       Whitney Houston|Angela Bassett|Loretta Devine|Lela Rochon|Gregory Hines|Dennis Haysbert|Michael Beach|Mykelti Williamson|Lamont Johnson|Wesley Snipes
# 11862                            Steve Martin|Diane Keaton|Martin Short|Kimberly Williams-Paisley|George Newbern|Kieran Culkin|BD Wong|Peter Michael Goetz|Kate McGregor-Stewart|Jane Adams|Eugene Levy|Lori Alan
#                                                                                                            ...
# 87098                                                                                                                                                                           Ed Asner|Sally Field|Ben Kingsley
# 80432     Eric Roberts|Peter Stormare|Sally Kirkland|Jsu Garcia|Howard Lazar|Sara Malakul Lane|Rick Ojeda|Sebastian Michael Barr|Nina Bergman|Matthew Albert Cole|Bill Cox|Claudia Craciun|Brandyn Cross|Laura...
# 2929                                                                                                                                                                   Mary Fuller|Charles Ogle|Augustus Phillips
# 72958                                                                                                                                        Nurul Islam Bablu|Russell Farazi|Jayanto Chattopadhyay|Rokeya Prachy
# 178535                                                                                                                                                                                                        NaN
# Name: cast, Length: 18635, dtype: object

# %%
df.cast.str.split("|", expand = True)
# Out:
#                       0               1                      2    \
# id
# 862             Tom Hanks       Tim Allen            Don Rickles
# 8844       Robin Williams   Jonathan Hyde          Kirsten Dunst
# 15602      Walter Matthau     Jack Lemmon            Ann-Margret
# 31357     Whitney Houston  Angela Bassett         Loretta Devine
# 11862        Steve Martin    Diane Keaton           Martin Short
# ...                   ...             ...                    ...
# 87098            Ed Asner     Sally Field           Ben Kingsley
# 80432        Eric Roberts  Peter Stormare         Sally Kirkland
# 2929          Mary Fuller    Charles Ogle      Augustus Phillips
# 72958   Nurul Islam Bablu  Russell Farazi  Jayanto Chattopadhyay
# 178535                NaN             NaN                    NaN
#
#                               3               4                  5    \
# id
# 862                    Jim Varney   Wallace Shawn  John Ratzenberger
# 8844               Bradley Pierce     Bonnie Hunt      Bebe Neuwirth
# 15602                Sophia Loren    Daryl Hannah   Burgess Meredith
# 31357                 Lela Rochon   Gregory Hines    Dennis Haysbert
# 11862   Kimberly Williams-Paisley  George Newbern      Kieran Culkin
# ...                           ...             ...                ...
# 87098                        None            None               None
# 80432                  Jsu Garcia    Howard Lazar  Sara Malakul Lane
# 2929                         None            None               None
# 72958               Rokeya Prachy            None               None
# 178535                        NaN             NaN                NaN
#
#                      6                       7                      8    \
# id
# 862          Annie Potts             John Morris        Erik von Detten
# 8844    David Alan Grier       Patricia Clarkson         Adam Hann-Byrd
# 15602       Kevin Pollak                    None                   None
# 31357      Michael Beach      Mykelti Williamson         Lamont Johnson
# 11862            BD Wong     Peter Michael Goetz  Kate McGregor-Stewart
# ...                  ...                     ...                    ...
# 87098               None                    None                   None
# 80432         Rick Ojeda  Sebastian Michael Barr           Nina Bergman
# 2929                None                    None                   None
# 72958               None                    None                   None
# 178535               NaN                     NaN                    NaN
#
#                         9             10               11             12   \
# id
# 862          Laurie Metcalf  R. Lee Ermey    Sarah Freeman  Penn Jillette
# 8844       Laura Bell Bundy   James Handy   Gillian Barber  Brandon Obray
# 15602                  None          None             None           None
# 31357         Wesley Snipes          None             None           None
# 11862            Jane Adams   Eugene Levy        Lori Alan           None
# ...                     ...           ...              ...            ...
# 87098                  None          None             None           None
# 80432   Matthew Albert Cole      Bill Cox  Claudia Craciun  Brandyn Cross
# 2929                   None          None             None           None
# 72958                  None          None             None           None
# 178535                  NaN           NaN              NaN            NaN
#
#                    13                  14   ...   298   299   300   301   302  \
# id                                          ...
# 862               None                None  ...  None  None  None  None  None
# 8844    Cyrus Thiedeke  Gary Joseph Thorup  ...  None  None  None  None  None
# 15602             None                None  ...  None  None  None  None  None
# 31357             None                None  ...  None  None  None  None  None
# 11862             None                None  ...  None  None  None  None  None
# ...                ...                 ...  ...   ...   ...   ...   ...   ...
# 87098             None                None  ...  None  None  None  None  None
# 80432   Laura Eichhorn       Jules Douglas  ...  None  None  None  None  None
# 2929              None                None  ...  None  None  None  None  None
# 72958             None                None  ...  None  None  None  None  None
# 178535             NaN                 NaN  ...  None  None  None  None  None
#
#          303   304   305   306   307   308   309   310   311   312
# id
# 862     None  None  None  None  None  None  None  None  None  None
# 8844    None  None  None  None  None  None  None  None  None  None
# 15602   None  None  None  None  None  None  None  None  None  None
# 31357   None  None  None  None  None  None  None  None  None  None
# 11862   None  None  None  None  None  None  None  None  None  None
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 87098   None  None  None  None  None  None  None  None  None  None
# 80432   None  None  None  None  None  None  None  None  None  None
# 2929    None  None  None  None  None  None  None  None  None  None
# 72958   None  None  None  None  None  None  None  None  None  None
# 178535  None  None  None  None  None  None  None  None  None  None
#
# [18635 rows x 313 columns]

# %%
act = df.cast.str.split("|", expand = True)
act
# Out:
#                       0               1                      2    \
# id
# 862             Tom Hanks       Tim Allen            Don Rickles
# 8844       Robin Williams   Jonathan Hyde          Kirsten Dunst
# 15602      Walter Matthau     Jack Lemmon            Ann-Margret
# 31357     Whitney Houston  Angela Bassett         Loretta Devine
# 11862        Steve Martin    Diane Keaton           Martin Short
# ...                   ...             ...                    ...
# 87098            Ed Asner     Sally Field           Ben Kingsley
# 80432        Eric Roberts  Peter Stormare         Sally Kirkland
# 2929          Mary Fuller    Charles Ogle      Augustus Phillips
# 72958   Nurul Islam Bablu  Russell Farazi  Jayanto Chattopadhyay
# 178535                NaN             NaN                    NaN
#
#                               3               4                  5    \
# id
# 862                    Jim Varney   Wallace Shawn  John Ratzenberger
# 8844               Bradley Pierce     Bonnie Hunt      Bebe Neuwirth
# 15602                Sophia Loren    Daryl Hannah   Burgess Meredith
# 31357                 Lela Rochon   Gregory Hines    Dennis Haysbert
# 11862   Kimberly Williams-Paisley  George Newbern      Kieran Culkin
# ...                           ...             ...                ...
# 87098                        None            None               None
# 80432                  Jsu Garcia    Howard Lazar  Sara Malakul Lane
# 2929                         None            None               None
# 72958               Rokeya Prachy            None               None
# 178535                        NaN             NaN                NaN
#
#                      6                       7                      8    \
# id
# 862          Annie Potts             John Morris        Erik von Detten
# 8844    David Alan Grier       Patricia Clarkson         Adam Hann-Byrd
# 15602       Kevin Pollak                    None                   None
# 31357      Michael Beach      Mykelti Williamson         Lamont Johnson
# 11862            BD Wong     Peter Michael Goetz  Kate McGregor-Stewart
# ...                  ...                     ...                    ...
# 87098               None                    None                   None
# 80432         Rick Ojeda  Sebastian Michael Barr           Nina Bergman
# 2929                None                    None                   None
# 72958               None                    None                   None
# 178535               NaN                     NaN                    NaN
#
#                         9             10               11             12   \
# id
# 862          Laurie Metcalf  R. Lee Ermey    Sarah Freeman  Penn Jillette
# 8844       Laura Bell Bundy   James Handy   Gillian Barber  Brandon Obray
# 15602                  None          None             None           None
# 31357         Wesley Snipes          None             None           None
# 11862            Jane Adams   Eugene Levy        Lori Alan           None
# ...                     ...           ...              ...            ...
# 87098                  None          None             None           None
# 80432   Matthew Albert Cole      Bill Cox  Claudia Craciun  Brandyn Cross
# 2929                   None          None             None           None
# 72958                  None          None             None           None
# 178535                  NaN           NaN              NaN            NaN
#
#                    13                  14   ...   298   299   300   301   302  \
# id                                          ...
# 862               None                None  ...  None  None  None  None  None
# 8844    Cyrus Thiedeke  Gary Joseph Thorup  ...  None  None  None  None  None
# 15602             None                None  ...  None  None  None  None  None
# 31357             None                None  ...  None  None  None  None  None
# 11862             None                None  ...  None  None  None  None  None
# ...                ...                 ...  ...   ...   ...   ...   ...   ...
# 87098             None                None  ...  None  None  None  None  None
# 80432   Laura Eichhorn       Jules Douglas  ...  None  None  None  None  None
# 2929              None                None  ...  None  None  None  None  None
# 72958             None                None  ...  None  None  None  None  None
# 178535             NaN                 NaN  ...  None  None  None  None  None
#
#          303   304   305   306   307   308   309   310   311   312
# id
# 862     None  None  None  None  None  None  None  None  None  None
# 8844    None  None  None  None  None  None  None  None  None  None
# 15602   None  None  None  None  None  None  None  None  None  None
# 31357   None  None  None  None  None  None  None  None  None  None
# 11862   None  None  None  None  None  None  None  None  None  None
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 87098   None  None  None  None  None  None  None  None  None  None
# 80432   None  None  None  None  None  None  None  None  None  None
# 2929    None  None  None  None  None  None  None  None  None  None
# 72958   None  None  None  None  None  None  None  None  None  None
# 178535  None  None  None  None  None  None  None  None  None  None
#
# [18635 rows x 313 columns]

# %%
act.stack().reset_index(level=1, drop=True).to_frame()
# Out:
#                            0
# id
# 862                Tom Hanks
# 862                Tim Allen
# 862              Don Rickles
# 862               Jim Varney
# 862            Wallace Shawn
# ...                      ...
# 2929       Augustus Phillips
# 72958      Nurul Islam Bablu
# 72958         Russell Farazi
# 72958  Jayanto Chattopadhyay
# 72958          Rokeya Prachy
#
# [280300 rows x 1 columns]

# %%
act = act.stack().reset_index(level=1, drop=True).to_frame()

# %%
act
# Out:
#                            0
# id
# 862                Tom Hanks
# 862                Tim Allen
# 862              Don Rickles
# 862               Jim Varney
# 862            Wallace Shawn
# ...                      ...
# 2929       Augustus Phillips
# 72958      Nurul Islam Bablu
# 72958         Russell Farazi
# 72958  Jayanto Chattopadhyay
# 72958          Rokeya Prachy
#
# [280300 rows x 1 columns]

# %%
act.columns = ["Actor"]

# %%
act = act.merge(df[["title", "revenue_musd", "vote_average", "popularity"]],
                how = "left", left_index = True, right_index = True)

# %%
act
# Out:
#                    Actor                title  revenue_musd  vote_average  \
# id
# 2            Turo Pajala                Ariel           NaN          7.10
# 2       Susanna Haavisto                Ariel           NaN          7.10
# 2        Matti Pellonpää                Ariel           NaN          7.10
# 2           Eetu Hilkamo                Ariel           NaN          7.10
# 3        Matti Pellonpää  Shadows in Paradise           NaN          7.10
# ...                  ...                  ...           ...           ...
# 445590      Jürgen Franz         Photographer           NaN           NaN
# 445590    Norbert Langer         Photographer           NaN           NaN
# 445590       Peter Matic         Photographer           NaN           NaN
# 445590   Szymon Szurmiej         Photographer           NaN           NaN
# 445590  Helmut Weestmann         Photographer           NaN           NaN
#
#         popularity
# id
# 2             3.86
# 2             3.86
# 2             3.86
# 2             3.86
# 3             2.29
# ...            ...
# 445590        0.00
# 445590        0.00
# 445590        0.00
# 445590        0.00
# 445590        0.00
#
# [280300 rows x 5 columns]

# %% [markdown]
# ## Most Successful Actors (Part 2)

# %%
act
# Out:
#                    Actor                title  revenue_musd  vote_average  \
# id
# 2            Turo Pajala                Ariel           NaN          7.10
# 2       Susanna Haavisto                Ariel           NaN          7.10
# 2        Matti Pellonpää                Ariel           NaN          7.10
# 2           Eetu Hilkamo                Ariel           NaN          7.10
# 3        Matti Pellonpää  Shadows in Paradise           NaN          7.10
# ...                  ...                  ...           ...           ...
# 445590      Jürgen Franz         Photographer           NaN           NaN
# 445590    Norbert Langer         Photographer           NaN           NaN
# 445590       Peter Matic         Photographer           NaN           NaN
# 445590   Szymon Szurmiej         Photographer           NaN           NaN
# 445590  Helmut Weestmann         Photographer           NaN           NaN
#
#         popularity
# id
# 2             3.86
# 2             3.86
# 2             3.86
# 2             3.86
# 3             2.29
# ...            ...
# 445590        0.00
# 445590        0.00
# 445590        0.00
# 445590        0.00
# 445590        0.00
#
# [280300 rows x 5 columns]

# %%
act.Actor.nunique()
# Out:
# 112043

# %%
act.Actor.unique()
# Out:
# array(['Turo Pajala', 'Susanna Haavisto', 'Matti Pellonpää', ...,
#        'Peter Matic', 'Szymon Szurmiej', 'Helmut Weestmann'], dtype=object)

# %%
act.Actor.value_counts().head(20)
# Out:
# Bess Flowers          156
# John Wayne            108
# Samuel L. Jackson      92
# Michael Caine          79
# Steve Buscemi          79
# Christopher Lee        78
# Robert De Niro         78
# John Carradine         76
# Donald Sutherland      75
# Dennis Hopper          71
# Christopher Walken     70
# Gérard Depardieu       69
# Harvey Keitel          69
# Robert Duvall          69
# Willem Dafoe           68
# Gene Hackman           67
# Bruce Willis           67
# Ward Bond              65
# Harry Dean Stanton     65
# M. Emmet Walsh         64
# Name: Actor, dtype: int64

# %%
plt.figure(figsize = (12, 8))
act.Actor.value_counts().head(20).plot(kind='bar', fontsize = 15)
plt.title("Most Active Actors",fontsize = 20)
plt.ylabel("Number of Movies", fontsize = 15)
plt.show()

# %%
agg = act.groupby("Actor").agg(Total_Revenue = ("revenue_musd", "sum"),
                               Mean_Revenue = ("revenue_musd", "mean"),
                               Mean_Rating = ("vote_average", "mean"),
                               Mean_Pop = ("popularity", "mean"),
                               Total_Movies = ("Actor", "count"))

# %%
agg.nlargest(10, "Total_Movies")
# Out:
#                    Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Bess Flowers              364.71         15.20         6.50      2.89
# John Wayne                236.09         11.24         5.77      3.37
# Samuel L. Jackson       11881.50        188.60         6.31     11.36
# Michael Caine            5757.90        169.35         6.34      8.31
# Steve Buscemi            4387.07         97.49         6.16      8.10
# Christopher Lee          7192.10        287.68         6.20      6.86
# Robert De Niro           4774.08         85.25         6.48      8.96
# John Carradine            255.84         19.68         5.87      3.19
# Donald Sutherland        3118.56         89.10         6.36      6.64
# Dennis Hopper            1077.10         29.11         6.03      5.41
#
#                    Total_Movies
# Actor
# Bess Flowers                156
# John Wayne                  108
# Samuel L. Jackson            92
# Michael Caine                79
# Steve Buscemi                79
# Christopher Lee              78
# Robert De Niro               78
# John Carradine               76
# Donald Sutherland            75
# Dennis Hopper                71

# %%
agg.nlargest(10, "Total_Revenue")
# Out:
#                    Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Samuel L. Jackson       11881.50        188.60         6.31     11.36
# Alan Rickman            10178.59        391.48         6.80     11.39
# Frank Welker            10165.25        290.44         6.32      9.76
# Warwick Davis            9934.06        584.36         6.45     14.55
# Gary Oldman              9480.69        338.60         6.60     14.08
# Robbie Coltrane          9430.97        428.68         6.47     10.32
# Timothy Spall            8963.70        407.44         6.67      9.78
# Tom Hanks                8949.43        241.88         6.59     11.94
# Hugo Weaving             8726.31        484.80         6.61     12.30
# John Ratzenberger        8591.14        429.56         6.84     14.00
#
#                    Total_Movies
# Actor
# Samuel L. Jackson            92
# Alan Rickman                 35
# Frank Welker                 51
# Warwick Davis                24
# Gary Oldman                  42
# Robbie Coltrane              38
# Timothy Spall                40
# Tom Hanks                    47
# Hugo Weaving                 25
# John Ratzenberger            25

# %%
plt.figure(figsize = (12, 8))
agg.Total_Revenue.nlargest(10).plot(kind='bar', fontsize = 15)
plt.title("Total Revenue",fontsize = 20)
plt.ylabel("Revenue (in MUSD)", fontsize = 15)
plt.show()

# %%
agg.Mean_Revenue.nlargest(10)
# Out:
# Actor
# Alicia Vela-Bailey   2787.97
# Allan Henry          2787.97
# Anthony Ingruber     2787.97
# April Marie Thomas   2787.97
# Ashley Jeffery       2787.97
# Austin Wilson        2787.97
# Brandon Jelkes       2787.97
# Bravita A. Threatt   2787.97
# Carvon Futrell       2787.97
# Chris Mala           2787.97
# Name: Mean_Revenue, dtype: float64

# %%
act[act.Actor == "Ashley Jeffery"]
# Out:
#                 Actor   title  revenue_musd  vote_average  popularity
# id
# 19995  Ashley Jeffery  Avatar       2787.97          7.20      185.07

# %%
agg[agg.Total_Movies >= 10].nlargest(10, "Mean_Revenue")
# Out:
#                       Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Gloria Stuart               1845.03       1845.03         6.45      4.97
# Keith Richards              2967.71        989.24         6.61      8.95
# Rupert Grint                7710.82        856.76         7.18     20.39
# Tom Felton                  8280.26        828.03         6.86     21.33
# Emma Watson                 7793.30        779.33         7.18     21.86
# Mark Williams               6872.09        763.57         6.76     13.72
# Adrian Rawlins              6777.57        753.06         6.75     16.04
# Daniel Radcliffe            7863.15        714.83         7.11     19.27
# Geraldine Somerville        7830.32        711.85         7.09     17.30
# Samuli Edelmann              694.71        694.71         5.92      2.33
#
#                       Total_Movies
# Actor
# Gloria Stuart                   12
# Keith Richards                  12
# Rupert Grint                    11
# Tom Felton                      14
# Emma Watson                     11
# Mark Williams                   16
# Adrian Rawlins                  14
# Daniel Radcliffe                12
# Geraldine Somerville            14
# Samuli Edelmann                 12

# %%
agg[agg.Total_Movies >= 10].nlargest(10, "Mean_Rating")
# Out:
#                  Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Daisuke Katô              0.42          0.14         7.81      4.21
# Nobuo Nakamura            0.06          0.06         7.77      4.60
# Takeshi Katô              4.34          2.17         7.67      6.92
# Akira Tani                0.33          0.16         7.65      5.04
# Kyôko Kagawa              0.00           NaN         7.61      4.24
# Setsuko Hara              0.00           NaN         7.61      2.91
# Haruko Sugimura           0.00           NaN         7.58      2.59
# Tatsuya Nakadai           4.34          2.17         7.57      4.70
# Akio Ohtsuka            265.91         53.18         7.57      8.87
# Minoru Chiaki             0.42          0.14         7.56      5.13
#
#                  Total_Movies
# Actor
# Daisuke Katô               15
# Nobuo Nakamura             11
# Takeshi Katô               10
# Akira Tani                 12
# Kyôko Kagawa               10
# Setsuko Hara               11
# Haruko Sugimura            15
# Tatsuya Nakadai            21
# Akio Ohtsuka               10
# Minoru Chiaki              14

# %%
agg[agg.Total_Movies >= 10].nlargest(10, "Mean_Pop")
# Out:
#                    Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Wes Studi                3677.08        367.71         6.38     28.66
# Sam Worthington          3834.99        426.11         6.14     22.75
# Laz Alonso               3579.71        397.75         6.28     22.18
# Emma Watson              7793.30        779.33         7.18     21.86
# Tom Felton               8280.26        828.03         6.86     21.33
# Rupert Grint             7710.82        856.76         7.18     20.39
# Joel David Moore         3056.21        382.03         5.97     20.22
# Zoe Saldana              4606.80        329.06         6.25     19.88
# Daniel Radcliffe         7863.15        714.83         7.11     19.27
# Bronagh Gallagher        1723.17        246.17         6.49     18.82
#
#                    Total_Movies
# Actor
# Wes Studi                    10
# Sam Worthington              13
# Laz Alonso                   11
# Emma Watson                  11
# Tom Felton                   14
# Rupert Grint                 11
# Joel David Moore             13
# Zoe Saldana                  18
# Daniel Radcliffe             12
# Bronagh Gallagher            13

# %% [markdown]
# # Movie Recomendation Sysytem

# %%
pip install surprise

# %% [markdown]
# # Preprocessing raw dataa

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate


import warnings; warnings.simplefilter('ignore')

# %%
md = pd. read_csv('/content/movies_metadata.csv')

# %%
md['genres'] = md['genres'].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
vote_counts = md[md['vote_count'].notnull()]['vote_count'].astype('int')
vote_averages = md[md['vote_average'].notnull()]['vote_average'].astype('int')
C = vote_averages.mean()
C
# Out:
# 5.244896612406511

# %%
m = vote_counts.quantile(0.95)
m
# Out:
# 434.0

# %%
md['year'] = pd.to_datetime(md['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)

# %%
qualified = md[(md['vote_count'] >= m) & (md['vote_count'].notnull()) & (md['vote_average'].notnull())][['title', 'year', 'vote_count', 'vote_average', 'popularity', 'genres']]
qualified['vote_count'] = qualified['vote_count'].astype('int')
qualified['vote_average'] = qualified['vote_average'].astype('int')
qualified.shape
# Out:
# (2274, 6)

# %%
def weighted_rating(x):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
qualified['wr'] = qualified.apply(weighted_rating, axis=1)

# %%
qualified = qualified.sort_values('wr', ascending=False).head(250)

# %% [markdown]
# # Recomender 1

# %%
links_small = pd.read_csv('/content/links_small.csv')
links_small = links_small[links_small['tmdbId'].notnull()]['tmdbId'].astype('int')

# %%
md = md.drop([19730, 29503, 35587])
smd = md[md['id'].isin(links_small)]
smd.shape
# Out:
# (0, 25)

# %% [markdown]
# We have 9099 movies avaiable in our small movies metadata dataset which is 5 times smaller than our original dataset of 45000 movies.

# %% [markdown]
# Movie Description Based Recommender

# %%
smd['tagline'] = smd['tagline'].fillna('')
smd['description'] = smd['overview'] + smd['tagline']
smd['description'] = smd['description'].fillna('')

# %%
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(smd['description'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-ef58c3d867ce> in <cell line: 2>()
#       1 tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
# ----> 2 tfidf_matrix = tf.fit_transform(smd['description'])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    2131             sublinear_tf=self.sublinear_tf,
#    2132         )
# -> 2133         X = super().fit_transform(raw_documents)
#    2134         self._tfidf.fit(X)
#    2135         # X is already a transformed view of raw_documents so
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1386                     break
#    1387
# -> 1388         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1389
#    1390         if self.binary:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1292             vocabulary = dict(vocabulary)
#    1293             if not vocabulary:
# -> 1294                 raise ValueError(
#    1295                     "empty vocabulary; perhaps the documents only contain stop words"
#    1296                 )
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
tfidf_matrix.shape

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
smd = smd.reset_index()
titles = smd['title']
indices = pd.Series(smd.index, index=smd['title'])

# %%
def get_recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31]
    movie_indices = [i[0] for i in sim_scores]
    return titles.iloc[movie_indices]

# %%
get_recommendations('The Godfather').head(10)

# %%
get_recommendations('The Dark Knight').head(10)

# %%
md['id'] = md['id'].astype('int')

# %%
import pandas as pd
import numpy as np

# %%
def convert_int(x):
    try:
        return int(x)
    except:
        return np.nan

# %%
id_map = pd.read_csv('/content/links_small.csv')[['movieId', 'tmdbId']]
id_map['tmdbId'] = id_map['tmdbId'].apply(convert_int)
id_map.columns = ['movieId', 'id']
id_map = id_map.merge(smd[['title', 'id']], on='id').set_index('title')

# %%
indices_map = id_map.set_index('id')

# %%
def hybrid(userId, title):
    idx = indices[title]
    tmdbId = id_map.loc[title]['id']
    #print(idx)
    movie_id = id_map.loc[title]['movieId']

    sim_scores = list(enumerate(cosine_sim[int(idx)]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:26]
    movie_indices = [i[0] for i in sim_scores]

    movies = smd.iloc[movie_indices][['title', 'vote_count', 'vote_average', 'year', 'id']]
    movies['est'] = movies['id'].apply(lambda x: svd.predict(userId, indices_map.loc[x]['movieId']).est)
    movies = movies.sort_values('est', ascending=False)
    return movies.head(10)

# %%
hybrid(1, 'Avatar')

# %%
hybrid(500, 'Avatar')
